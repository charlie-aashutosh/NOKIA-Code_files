# %%
import numpy as np
import pandas as pd

# %%
#reading a .csv file
telecom=pd.read_csv("/content/Telecom_Transaction_Data.csv")

# %%
#reading a .json file
telecom_json=pd.read_json("/content/Telecom_Transaction_Data.json",lines=True)

# %%
telecom_json.head(10) #first 10 rows
# Out:
#   Transaction_ID Customer_ID Date_of_Transaction Service_Type Customer_Plan  \
# 0    TRANS-00001   CUST-0072          2023-03-11   Television         Basic
# 1    TRANS-00002   CUST-0104          2023-03-15     Landline      Standard
# 2    TRANS-00003   CUST-0147          2024-05-28    Broadband         Basic
# 3    TRANS-00004   CUST-0031          2023-01-10       Mobile         Basic
# 4    TRANS-00005   CUST-0106          2022-12-05    Broadband         Basic
# 5    TRANS-00006   CUST-0131          2023-08-15   Television      Standard
# 6    TRANS-00007   CUST-0014          2024-08-31       Mobile         Basic
# 7    TRANS-00008   CUST-0184          2023-09-21   Television         Basic
# 8    TRANS-00009   CUST-0195          2023-03-05       Mobile     Unlimited
# 9    TRANS-00010   CUST-0163          2023-12-20       Mobile       Premium
#
#    Bill_Amount Payment_Method Transaction_Status Complaint_Flag
# 0       346.72  Bank Transfer            Pending             No
# ...

# %%
telecom_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Transaction_ID       1000 non-null   object
#  1   Customer_ID          1000 non-null   object
#  2   Date_of_Transaction  1000 non-null   object
#  3   Service_Type         1000 non-null   object
#  4   Customer_Plan        1000 non-null   object
#  5   Bill_Amount          1000 non-null   float64
#  6   Payment_Method       1000 non-null   object
#  7   Transaction_Status   1000 non-null   object
#  8   Complaint_Flag       1000 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 70.4+ KB

# %%
telecom_json.describe() #statistical analysis
# Out:
#        Bill_Amount
# count  1000.000000
# mean   2499.620730
# std    1389.888499
# min     100.450000
# 25%    1275.905000
# 50%    2508.485000
# 75%    3653.375000
# max    4992.320000

# %%
telecom_json.describe(include='object') #categorical columns also
# Out:
#        Transaction_ID Customer_ID Date_of_Transaction Service_Type  \
# count            1000        1000                1000         1000
# unique           1000         197                 547            4
# top       TRANS-00001   CUST-0147          2023-07-23   Television
# freq                1          12                   5          280
#
#        Customer_Plan Payment_Method Transaction_Status Complaint_Flag
# count           1000           1000               1000           1000
# unique             4              4                  3              2
# top            Basic    Credit Card             Failed             No
# freq             297            269                345            507

# %%
#check for missing values
missing_values=telecom_json.isnull().sum()

# %%
print(missing_values)
# Out:
# Transaction_ID         0
# Customer_ID            0
# Date_of_Transaction    0
# Service_Type           0
# Customer_Plan          0
# Bill_Amount            0
# Payment_Method         0
# Transaction_Status     0
# Complaint_Flag         0
# dtype: int64

# %% [markdown]
# For numerical data - mean or median to impute the missing values
#
# For categorical data - mode to replace the missing value

# %%
def call_cost(duration, time):
  if 9<=time<=19:
    return duration*1 #peak hours - Rs 1 per minute
  else:
    return duration*0.5 #off hours - Rs 0.5 per minute

# %%
call_durations = [120, 200, 150, 190, 175, 300]

for i in call_durations:
  if i>180:
    print("suspicious calls detected.")
  else:
    print("normal call")
# Out:
# normal call
# suspicious calls detected.
# normal call
# suspicious calls detected.
# normal call
# suspicious calls detected.

# %%
call_durations = [120, 200, 150, 190, 175, 300]
if call_durations>180
       print("suspicious calls detected.")

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/telecome data.csv")

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# Descriptive statistics

# %%
tenure_analysis=data['tenure'].describe()

# %%
print(tenure_analysis)
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
mean_tenure=tenure_analysis['mean']

# %%
print(mean_tenure)
# Out:
# 32.37114865824223

# %%
max_tenure=tenure_analysis['max']

# %%
print(max_tenure)
# Out:
# 72.0

# %%
median_tenure=data['tenure'].median()

# %%
print(median_tenure)
# Out:
# 29.0

# %%
mode_tenure=data['tenure'].mode()[0]

# %%
print(mode_tenure)
# Out:
# 1

# %%
sum_tenure=data['tenure'].sum()

# %%
print(sum_tenure)
# Out:
# 227990

# %%
var_tenure=data['tenure'].var()

# %%
print(var_tenure)
# Out:
# 603.1681081237256

# %%
std_tenure=tenure_analysis['std']

# %%
print(std_tenure)
# Out:
# 24.55948102309423

# %%
#Descriptive statistics on - MonthlyCharges	like median, sum, std, mean, max min from the data
df=data['MonthlyCharges']

# %%
df.describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# Exploratory Data Analysis (EDA) or Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#plotting histogram
plt.figure(figsize=(10,5))
sns.histplot(data['MonthlyCharges'],bins=50) #bins represent the width of the bars
plt.title("histogram of monthly charges")
plt.xlabel("monthly charges")
plt.ylabel("frequency")
plt.show()

# %%
#plotting histogram
plt.figure(figsize=(10,5))
sns.histplot(data['tenure'],bins=50) #bins represent the width of the bars
plt.title("histogram of tenure")
plt.xlabel("tenure")
plt.ylabel("frequency")
plt.show()

# %%
#plotting histogram
plt.figure(figsize=(10,5))
plt.hist(data['MonthlyCharges'],bins=100) #bins represent the width of the bars
plt.title("histogram of monthly charges")
plt.xlabel("monthly charges")
plt.ylabel("frequency")
plt.show()

# %% [markdown]
# - Imbalanced Data --- Balanced Data => Standardization (Z Statistics)
#
# - Balanced Data --- Gaussian curve => Normalization

# %%
#pie chart
partner_count=data['Partner'].value_counts()
plt.figure(figsize=(5,5))
partner_count.plot.pie(autopct='%0.4f',colors=['skyblue','orange'])
plt.title("partner % distribution")
plt.show()

# %%
partner_count=data['Partner'].value_counts()
print(partner_count)
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="gender",data=data, palette='viridis')
plt.title("gender distribution")
plt.show()
# Out:
# <ipython-input-46-cc4e3cf134ab>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="gender",data=data, palette='viridis')

# %%
#Box plot
plt.figure(figsize=(10,5))
sns.boxplot(x=data['MonthlyCharges'])
plt.title("Boxplot : Monthly charges")
plt.xlabel("Monthly charges")
plt.show()

# %%
#Box plot
plt.figure(figsize=(10,5))
sns.boxplot(x=data['tenure'])
plt.title("Boxplot : tenure")
plt.xlabel("tenure")
plt.show()

# %%
#box plot for monthlycharges across churn status
plt.figure(figsize=(10,5))
sns.boxplot(x='Churn',y='MonthlyCharges',data=data)
plt.title("Boxplot : Monthly charges by Churn")
plt.xlabel("Churn")
plt.ylabel("Monthly Charges")
plt.show()

# %%
#scatter plot
plt.figure(figsize=(10,5))
sns.scatterplot(x=data['MonthlyCharges'].iloc[0:500],y=data['TotalCharges'].iloc[0:500])
plt.title("Monthly charges v/s Total charges")
plt.xlabel("Monthly charges")
plt.ylabel("Total charges")
plt.show()

# %%
telecom_df=pd.read_csv("/content/telecom_df.csv")

# %%
telecom_df.head()
# Out:
#    TowerID Location   Operator      Band  Traffic  Uptime  Faults  \
# 0        1     West  Operator2   800 MHz    72.53   94.71       2
# 1        2    North  Operator2   800 MHz    77.58   93.61       2
# 2        3  Central  Operator3  2100 MHz    96.94   94.29       1
# 3        4  Central  Operator3  1800 MHz   101.87   98.55       2
# 4        5     East  Operator1  2300 MHz    72.89   88.82       2
#
#   Faults_Class Uptime_Class  Traffic_per_Fault  ...  Fault_Severity_Index  \
# 0         High   Low Uptime             36.265  ...                 3.645
# 1         High   Low Uptime             38.790  ...                 4.195
# 2          Low   Low Uptime             96.940  ...                 3.355
# 3         High  High Uptime             50.935  ...                 1.725
# 4         High   Low Uptime             36.445  ...                 6.590
#
#    Log_Traffic  Log_Downtime  Log_Traffic_per_Fault  Uptime_Traffic  \
# ...

# %%
telecom_df.describe()
# Out:
#            TowerID      Traffic       Uptime       Faults  Traffic_per_Fault  \
# count  5050.000000  5050.000000  5050.000000  5050.000000        5050.000000
# mean   2498.113465    98.377715    95.183196     2.076832          62.892973
# std    1444.927164    22.703489     5.037763     1.941417          34.920754
# min       1.000000   -12.030000    79.160000    -1.000000          -0.537000
# 25%    1246.250000    85.392500    91.830000     1.000000          33.781667
# 50%    2496.500000    99.140000    95.170000     2.000000          53.235000
# 75%    3747.750000   112.675000    98.527500     3.000000          93.750000
# max    5000.000000   169.440000   114.220000    20.000000         169.440000
#
#           Downtime  Fault_Severity_Index  Log_Traffic  Log_Downtime  \
# count  5050.000000           5050.000000  5050.000000   5050.000000
# mean      4.816804              3.446818     4.588227      1.674628
# std       5.037763              2.625178     0.213009      0.850561
# ...

# %%
telecom_df.isnull().sum()
# Out:
# TowerID                    0
# Location                  50
# Operator                  16
# Band                      16
# Traffic                    0
# Uptime                     0
# Faults                     0
# Faults_Class               0
# Uptime_Class               0
# Traffic_per_Fault          0
# Downtime                   0
# Fault_Severity_Index       0
# Log_Traffic               50
# Log_Downtime             620
# Log_Traffic_per_Fault      0
# Uptime_Traffic             0
# Traffic_per_Downtime       0
# Traffic_Squared            0
# Uptime_Squared             0
# Traffic_Bin                0
# Uptime_Bin               857
# dtype: int64

# %%
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5050 entries, 0 to 5049
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   TowerID                5050 non-null   int64
#  1   Location               5000 non-null   object
#  2   Operator               5034 non-null   object
#  3   Band                   5034 non-null   object
#  4   Traffic                5050 non-null   float64
#  5   Uptime                 5050 non-null   float64
#  6   Faults                 5050 non-null   int64
#  7   Faults_Class           5050 non-null   object
#  8   Uptime_Class           5050 non-null   object
#  9   Traffic_per_Fault      5050 non-null   float64
#  10  Downtime               5050 non-null   float64
#  11  Fault_Severity_Index   5050 non-null   float64
#  12  Log_Traffic            5000 non-null   float64
#  13  Log_Downtime           4430 non-null   float64
# ...

# %%
#handling missing values
telecom_df['Location']=telecom_df['Location'].fillna(telecom_df['Location'].mode()[0])
telecom_df['Operator']=telecom_df['Operator'].fillna(telecom_df['Operator'].mode()[0])
telecom_df['Band']=telecom_df['Band'].fillna(telecom_df['Band'].mode()[0])
telecom_df['Log_Traffic']=telecom_df['Log_Traffic'].fillna(telecom_df['Log_Traffic'].mean())
telecom_df['Log_Downtime']=telecom_df['Log_Downtime'].fillna(telecom_df['Log_Downtime'].mean())
telecom_df['Uptime_Bin']=telecom_df['Uptime_Bin'].fillna(telecom_df['Uptime_Bin'].mode()[0])

# %%
telecom_df.isnull().sum()
# Out:
# TowerID                  0
# Location                 0
# Operator                 0
# Band                     0
# Traffic                  0
# Uptime                   0
# Faults                   0
# Faults_Class             0
# Uptime_Class             0
# Traffic_per_Fault        0
# Downtime                 0
# Fault_Severity_Index     0
# Log_Traffic              0
# Log_Downtime             0
# Log_Traffic_per_Fault    0
# Uptime_Traffic           0
# Traffic_per_Downtime     0
# Traffic_Squared          0
# Uptime_Squared           0
# Traffic_Bin              0
# Uptime_Bin               0
# dtype: int64
